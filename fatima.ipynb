# %%
import pandas as pd
import numpy as np

# %%
data2020=pd.read_csv('2020data.csv')
data2023=pd.read_csv('2023data.csv')

# %%
data2023
# Out:
#        assembly    model    year  engine  transmission  mileage      price
# 0           NaN  Corolla  2013.0  1300.0           NaN   145000  2870000.0
# 1           NaN     City  2000.0  1300.0           NaN   230000   995000.0
# 2           NaN    Yaris  2021.0  1300.0           NaN    60500  3585000.0
# 3           NaN    Swift  2017.0  1300.0           NaN    87000  2250000.0
# 4           NaN    Civic  2017.0  1800.0           NaN    86000  4850000.0
# ...         ...      ...     ...     ...           ...      ...        ...
# 77873       NaN    Civic  2019.0  1800.0           NaN    58000  5590000.0
# 77874       NaN     Alto  2015.0   660.0           NaN    65000  2420000.0
# 77875       NaN       HS  2021.0  1490.0           NaN     5000  7500000.0
# 77876       NaN   Baleno  2005.0  1300.0           NaN    19000  1250000.0
# 77877       NaN  Corolla  1998.0  1600.0           NaN    12345  1150000.0
#
# [77878 rows x 7 columns]

# %%
#cleaning 2023 Dataset
data2023.drop(['addref','color','city','registered','fuel','make','body'],axis=1,errors='ignore',inplace=True)
data2023['transmission'] = data2023['transmission'].map({'Automatic': 1, 'Manual': 0})
data2023
# Out:
#        assembly    model    year  engine  transmission  mileage      price
# 0             0  Corolla  2013.0  1300.0           NaN   145000  2870000.0
# 1             0     City  2000.0  1300.0           NaN   230000   995000.0
# 2             0    Yaris  2021.0  1300.0           NaN    60500  3585000.0
# 3             0    Swift  2017.0  1300.0           NaN    87000  2250000.0
# 4             0    Civic  2017.0  1800.0           NaN    86000  4850000.0
# ...         ...      ...     ...     ...           ...      ...        ...
# 77873         0    Civic  2019.0  1800.0           NaN    58000  5590000.0
# 77874         1     Alto  2015.0   660.0           NaN    65000  2420000.0
# 77875         1       HS  2021.0  1490.0           NaN     5000  7500000.0
# 77876         0   Baleno  2005.0  1300.0           NaN    19000  1250000.0
# 77877         1  Corolla  1998.0  1600.0           NaN    12345  1150000.0
#
# [77878 rows x 7 columns]

# %%
data2023['assembly'].fillna("local", inplace=True)
data2023['assembly'] = data2023['assembly'].map({'Imported': 1, 'local': 0})
data2023
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_34420\1580519628.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data2023['assembly'].fillna("local", inplace=True)
#        assembly    model    year  engine  transmission  mileage      price
# 0           NaN  Corolla  2013.0  1300.0           NaN   145000  2870000.0
# 1           NaN     City  2000.0  1300.0           NaN   230000   995000.0
# 2           NaN    Yaris  2021.0  1300.0           NaN    60500  3585000.0
# 3           NaN    Swift  2017.0  1300.0           NaN    87000  2250000.0
# 4           NaN    Civic  2017.0  1800.0           NaN    86000  4850000.0
# ...         ...      ...     ...     ...           ...      ...        ...
# 77873       NaN    Civic  2019.0  1800.0           NaN    58000  5590000.0
# 77874       NaN     Alto  2015.0   660.0           NaN    65000  2420000.0
# 77875       NaN       HS  2021.0  1490.0           NaN     5000  7500000.0
# 77876       NaN   Baleno  2005.0  1300.0           NaN    19000  1250000.0
# 77877       NaN  Corolla  1998.0  1600.0           NaN    12345  1150000.0
#
# [77878 rows x 7 columns]

# %%
data2023["model"].value_counts().head(5)
# Out:
# model
# Corolla    12871
# Civic       8275
# City        5277
# Mehran      4588
# Cultus      4463
# Name: count, dtype: int64

# %%
corolla_df = data2023[data2023['model'] == 'Corolla']
civic_df = data2023[data2023['model'] == 'Civic']
city_df = data2023[data2023['model'] == 'City']
mehran_df = data2023[data2023['model'] == 'Mehran']
cultus_df = data2023[data2023['model'] == 'Cultus']
cultus_df
# Out:
#        assembly       body    make   model    year  engine  transmission  \
# 18            0  Hatchback  Suzuki  Cultus  2019.0  1000.0             0
# 22            0  Hatchback  Suzuki  Cultus  2017.0  1000.0             0
# 110           0  Hatchback  Suzuki  Cultus  2017.0  1000.0             0
# 114           0        NaN  Suzuki  Cultus  2018.0  1000.0             1
# 138           0  Hatchback  Suzuki  Cultus  2018.0  1000.0             1
# ...         ...        ...     ...     ...     ...     ...           ...
# 77796         0  Hatchback  Suzuki  Cultus  2015.0  1000.0             0
# 77809         0  Hatchback  Suzuki  Cultus  2015.0  1000.0             0
# 77830         0  Hatchback  Suzuki  Cultus  2008.0  1000.0             0
# 77842         0  Hatchback  Suzuki  Cultus  2007.0  1000.0             0
# 77867         0  Hatchback  Suzuki  Cultus  2002.0  1000.0             0
#
#        mileage      price
# 18       96200  2950000.0
# 22       52500  2505000.0
# 110      39807  1695000.0
# 114      65000  2870000.0
# 138      72000  3100000.0
# ...        ...        ...
# 77796    76357  1470000.0
# 77809    79000  1400000.0
# 77830    60800   990000.0
# 77842   100000   725000.0
# 77867       15   820000.0
#
# [4463 rows x 9 columns]
